# %%
import json
from datetime import datetime
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

from google.cloud import storage

# %%
BUCKET = "rjr-portal-da-transparencia"
YEAR = 2020

# %%
def load_json(name):
    bucket = storage.Client().get_bucket(BUCKET)
    blob = bucket.blob(f'aux/{name}.json')
    maps = json.loads(blob.download_as_string())
    return maps


def mapping(df, map_, column, type_return):
    map_func = udf(lambda key: map_.get(str(key)), type_return())
    df = df.withColumn(column, map_func(col(column)))
    return df

def string_to_date(df, column, year):
    if year > 2014:
        pattern = '%d/%m/%Y'
    else:
        pattern = "%d%b%Y:%H:%M:%S"
    map_func =  udf (lambda date: datetime.strptime(date, pattern) 
                     if type(date) == str 
                     else None, DateType())
    df = df.withColumn(column, map_func(col(column)))
    return df

# %%
spark = SparkSession.builder.appName("censo").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True)

# %%
schema = load_json("schemas/docentes_schema")
schema = StructType.fromJson(schema)
# except:
#     schema = StructType.fromJson(json.loads(schema))

# %%
schema = load_json("escolas_schema")
schema = StructType.fromJson(schema)
df = spark \
    .read \
    .options(header=True, delimiter="|", encoding="utf8") \
    .schema(schema=schema) \
    .csv(f"gs://{BUCKET}/landing_zone/censo-escolar/{YEAR}/escolas.csv" )

# %%
maps = load_json("maps")
string_columns = [column for column in df.columns 
                  if column.startswith("TP") or column.startswith("CO")]

for column in string_columns:
    if column in maps:
        df = mapping(df, maps[column], column, StringType)
    else:
        print(column)
# Out:
# CO_ENTIDADE
# CO_DISTRITO
# CO_ESCOLA_SEDE_VINCULADA

# %%
bool_columns = [column for column in df.columns 
                  if column.startswith("IN")]

mapping_bool = {
    "0": False,
    "1": True
}

for column in bool_columns:
    df = mapping(df, mapping_bool, column, BooleanType)

# %%
df = string_to_date(df, "DT_ANO_LETIVO_INICIO", YEAR)
df = string_to_date(df, "DT_ANO_LETIVO_TERMINO", YEAR)

# %%
df
# Out:
# DataFrame[NU_ANO_CENSO: string, CO_ENTIDADE: string, NO_ENTIDADE: string, CO_ORGAO_REGIONAL: string, TP_SITUACAO_FUNCIONAMENTO: string, DT_ANO_LETIVO_INICIO: date, DT_ANO_LETIVO_TERMINO: date, CO_REGIAO: string, CO_MESORREGIAO: string, CO_MICRORREGIAO: string, CO_UF: string, CO_MUNICIPIO: string, CO_DISTRITO: string, TP_DEPENDENCIA: string, TP_LOCALIZACAO: string, TP_CATEGORIA_ESCOLA_PRIVADA: string, IN_CONVENIADA_PP: boolean, TP_CONVENIO_PODER_PUBLICO: string, IN_MANT_ESCOLA_PRIVADA_EMP: boolean, IN_MANT_ESCOLA_PRIVADA_ONG: boolean, IN_MANT_ESCOLA_PRIVADA_SIND: boolean, IN_MANT_ESCOLA_PRIVADA_SIST_S: boolean, IN_MANT_ESCOLA_PRIVADA_S_FINS: boolean, CO_ESCOLA_SEDE_VINCULADA: string, CO_IES_OFERTANTE: string, TP_REGULAMENTACAO: string, IN_LOCAL_FUNC_PREDIO_ESCOLAR: boolean, TP_OCUPACAO_PREDIO_ESCOLAR: string, IN_LOCAL_FUNC_SALAS_EMPRESA: boolean, IN_LOCAL_FUNC_SOCIOEDUCATIVO: boolean, IN_LOCAL_FUNC_UNID_PRISIONAL: boolean, IN_LOCAL_FUNC_PRISIONAL_SOCIO: boolean, IN_LOCAL_FUNC_TEMPLO_IGREJA: boolean, IN_LOCAL_FUNC_CASA_PROFESSOR: boolean, IN_LOCAL_FUNC_GALPAO: boolean, TP_OCUPACAO_GALPAO: string, IN_LOCAL_FUNC_SALAS_OUTRA_ESC: boolean, IN_LOCAL_FUNC_OUTROS: boolean, IN_PREDIO_COMPARTILHADO: boolean, IN_AGUA_FILTRADA: boolean, IN_AGUA_REDE_PUBLICA: boolean, IN_AGUA_POCO_ARTESIANO: boolean, IN_AGUA_CACIMBA: boolean, IN_AGUA_FONTE_RIO: boolean, IN_AGUA_INEXISTENTE: boolean, IN_ENERGIA_REDE_PUBLICA: boolean, IN_ENERGIA_GERADOR: boolean, IN_ENERGIA_OUTROS: boolean, IN_ENERGIA_INEXISTENTE: boolean, IN_ESGOTO_REDE_PUBLICA: boolean, IN_ESGOTO_FOSSA: boolean, IN_ESGOTO_INEXISTENTE: boolean, IN_LIXO_COLETA_PERIODICA: boolean, IN_LIXO_QUEIMA: boolean, IN_LIXO_JOGA_OUTRA_AREA: boolean, IN_LIXO_RECICLA: boolean, IN_LIXO_ENTERRA: boolean, IN_LIXO_OUTROS: boolean, IN_SALA_DIRETORIA: boolean, IN_SALA_PROFESSOR: boolean, IN_LABORATORIO_INFORMATICA: boolean, IN_LABORATORIO_CIENCIAS: boolean, IN_SALA_ATENDIMENTO_ESPECIAL: boolean, IN_QUADRA_ESPORTES_COBERTA: boolean, IN_QUADRA_ESPORTES_DESCOBERTA: boolean, IN_QUADRA_ESPORTES: boolean, IN_COZINHA: boolean, IN_BIBLIOTECA: boolean, IN_SALA_LEITURA: boolean, IN_BIBLIOTECA_SALA_LEITURA: boolean, IN_PARQUE_INFANTIL: boolean, IN_BERCARIO: boolean, IN_BANHEIRO_FORA_PREDIO: boolean, IN_BANHEIRO_DENTRO_PREDIO: boolean, IN_BANHEIRO_EI: boolean, IN_BANHEIRO_PNE: boolean, IN_DEPENDENCIAS_PNE: boolean, IN_SECRETARIA: boolean, IN_BANHEIRO_CHUVEIRO: boolean, IN_REFEITORIO: boolean, IN_DESPENSA: boolean, IN_ALMOXARIFADO: boolean, IN_AUDITORIO: boolean, IN_PATIO_COBERTO: boolean, IN_PATIO_DESCOBERTO: boolean, IN_ALOJAM_ALUNO: boolean, IN_ALOJAM_PROFESSOR: boolean, IN_AREA_VERDE: boolean, IN_LAVANDERIA: boolean, IN_DEPENDENCIAS_OUTRAS: boolean, NU_SALAS_EXISTENTES: string, NU_SALAS_UTILIZADAS: string, IN_EQUIP_TV: boolean, IN_EQUIP_VIDEOCASSETE: boolean, IN_EQUIP_DVD: boolean, IN_EQUIP_PARABOLICA: boolean, IN_EQUIP_COPIADORA: boolean, IN_EQUIP_RETROPROJETOR: boolean, IN_EQUIP_IMPRESSORA: boolean, IN_EQUIP_IMPRESSORA_MULT: boolean, IN_EQUIP_SOM: boolean, IN_EQUIP_MULTIMIDIA: boolean, IN_EQUIP_FAX: boolean, IN_EQUIP_FOTO: boolean, IN_COMPUTADOR: boolean, NU_EQUIP_TV: string, NU_EQUIP_VIDEOCASSETE: string, NU_EQUIP_DVD: string, NU_EQUIP_PARABOLICA: string, NU_EQUIP_COPIADORA: string, NU_EQUIP_RETROPROJETOR: string, NU_EQUIP_IMPRESSORA: string, NU_EQUIP_IMPRESSORA_MULT: string, NU_EQUIP_SOM: string, NU_EQUIP_MULTIMIDIA: string, NU_EQUIP_FAX: string, NU_EQUIP_FOTO: string, NU_COMPUTADOR: string, NU_COMP_ADMINISTRATIVO: string, NU_COMP_ALUNO: string, IN_INTERNET: boolean, IN_BANDA_LARGA: boolean, NU_FUNCIONARIOS: string, IN_ALIMENTACAO: boolean, TP_AEE: string, TP_ATIVIDADE_COMPLEMENTAR: string, IN_FUNDAMENTAL_CICLOS: boolean, TP_LOCALIZACAO_DIFERENCIADA: string, IN_MATERIAL_ESP_QUILOMBOLA: boolean, IN_MATERIAL_ESP_INDIGENA: boolean, IN_MATERIAL_ESP_NAO_UTILIZA: boolean, IN_EDUCACAO_INDIGENA: boolean, TP_INDIGENA_LINGUA: string, CO_LINGUA_INDIGENA: string, IN_BRASIL_ALFABETIZADO: boolean, IN_FINAL_SEMANA: boolean, IN_FORM ...
